# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=(r"C:\Users\praji\Downloads\house_price.csv")
df=pd.read_csv(data)
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13196                     other      4 BHK      3600.0     5  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0     4  488.00    4
# 13199              Doddathoguru      1 BHK       550.0     1   17.00    1
#
#        price_per_sqft  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# ...

# %%
#mean
df.price_per_sqft.mean()
# Out:
# 7920.336742424242

# %%
 #percentail method
df.price_per_sqft.quantile([0.25,0.50,0.75])
# Out:
# 0.25    4267.0
# 0.50    5438.0
# 0.75    7317.0
# Name: price_per_sqft, dtype: float64

# %%
q1=df.price_per_sqft.quantile(0.25)

# %%
q3=df.price_per_sqft.quantile(0.75)

# %%
q1,q3
# Out:
# (4267.0, 7317.0)

# %%
IQR=q3-q1
IQR
# Out:
# 3050.0

# %%
lower_whisker=q1-1.5*IQR
upper_whisker=q3+1.5*IQR
print ("Lower Wisker: ",lower_whisker)
print("Upper Wisker: ",upper_whisker)
# Out:
# Lower Wisker:  -308.0
# Upper Wisker:  11892.0

# %%
data_outlier=df[(df.price_per_sqft<lower_whisker)|(df.price_per_sqft>upper_whisker)]
data_outlier
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 7          Rajaji Nagar      4 BHK      3300.0     4  600.0    4
# 9                 other  6 Bedroom      1020.0     6  370.0    6
# 22          Thanisandra  4 Bedroom      2800.0     5  380.0    4
# 45           HSR Layout  8 Bedroom       600.0     9  200.0    8
# 48             KR Puram  2 Bedroom       800.0     1  130.0    2
# ...                 ...        ...         ...   ...    ...  ...
# 13142             other      2 BHK      1140.0     1  185.0    2
# 13157             other  7 Bedroom      1400.0     7  218.0    7
# 13185          Hulimavu      1 BHK       500.0     1  220.0    1
# 13186             other  4 Bedroom      1200.0     5  325.0    4
# 13191  Ramamurthy Nagar  7 Bedroom      1500.0     9  250.0    7
#
#        price_per_sqft  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# 7               18181         NaN         NaN         NaN         NaN
# ...

# %%
df['price_per_sqft'].describe().round()
# Out:
# count       13200.0
# mean         7920.0
# std        106727.0
# min           267.0
# 25%          4267.0
# 50%          5438.0
# 75%          7317.0
# max      12000000.0
# Name: price_per_sqft, dtype: float64

# %%
# Non Outlier
data=df[(df.price_per_sqft>lower_whisker) & (df.price_per_sqft<upper_whisker)]
data
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13196                     other      4 BHK      3600.0     5  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0     4  488.00    4
# 13199              Doddathoguru      1 BHK       550.0     1   17.00    1
#
#        price_per_sqft  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# ...

# %%
sns.histplot(data['price_per_sqft'], kde=True)
plt.xlabel('Price per Sqft')
plt.ylabel('Frequency')
plt.title('Distribution of Price per Sqft')
plt.show()

# %%
m=df.price_per_sqft.mean()
s=df.price_per_sqft.std()
print (m)
print(s)
# Out:
# 7920.336742424242
# 106727.16032810867

# %%
df["Zscore"]=(df.price_per_sqft-m)/s
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13196                     other      4 BHK      3600.0     5  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0     4  488.00    4
# 13199              Doddathoguru      1 BHK       550.0     1   17.00    1
#
#        price_per_sqft  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# ...

# %%
df[(df.Zscore>-3) & (df.Zscore<3)]
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13196                     other      4 BHK      3600.0     5  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0     4  488.00    4
# 13199              Doddathoguru      1 BHK       550.0     1   17.00    1
#
#        price_per_sqft  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  \
# ...

# %%
data1=df.drop(["location","size","Zscore"],axis=1)
data1
# Out:
#        total_sqft  bath   price  bhk  price_per_sqft  Unnamed: 7  Unnamed: 8  \
# 0          1056.0     2   39.07    2            3699         NaN         NaN
# 1          2600.0     5  120.00    4            4615         NaN         NaN
# 2          1440.0     2   62.00    3            4305         NaN         NaN
# 3          1521.0     3   95.00    3            6245         NaN         NaN
# 4          1200.0     2   51.00    2            4250         NaN         NaN
# ...           ...   ...     ...  ...             ...         ...         ...
# 13195      3453.0     4  231.00    5            6689         NaN         NaN
# 13196      3600.0     5  400.00    4           11111         NaN         NaN
# 13197      1141.0     2   60.00    2            5258         NaN         NaN
# 13198      4689.0     4  488.00    4           10407         NaN         NaN
# 13199       550.0     1   17.00    1            3090         NaN         NaN
#
# ...

# %%
numeric_data1=data1.select_dtypes(include='number').drop(columns=['df'],errors='ignore')
cor1=numeric_data1.corr()
cor1
# Out:
#                 total_sqft      bath     price       bhk  price_per_sqft  \
# total_sqft        1.000000  0.392743  0.574330  0.346013       -0.008267
# bath              0.392743  1.000000  0.455998  0.897951        0.030883
# price             0.574330  0.455998  1.000000  0.396883        0.028387
# bhk               0.346013  0.897951  0.396883  1.000000        0.030955
# price_per_sqft   -0.008267  0.030883  0.028387  0.030955        1.000000
# Unnamed: 7             NaN       NaN       NaN       NaN             NaN
# Unnamed: 8             NaN       NaN       NaN       NaN             NaN
# Unnamed: 9             NaN       NaN       NaN       NaN             NaN
# Unnamed: 11            NaN       NaN       NaN       NaN             NaN
# Unnamed: 12            NaN       NaN       NaN       NaN             NaN
#
#                 Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 11  Unnamed: 12
# total_sqft             NaN         NaN         NaN          NaN          NaN
# ...

# %%
sns.heatmap(cor1,annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df)
plt.title("Box plotfor all the numerical columns")
plt.show()

# %%
g=df.drop(["Zscore"],axis=1)
sns.pairplot(g, diag_kind='kde')
plt.show()
# Out:
# C:\Users\praji\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
